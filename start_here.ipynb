# %%
import pandas as pd
import numpy as np
# you might need to install lxml

from src.load_data import get_df

# %%
df = get_df()
df
# Out:
#     WAHLPERIODE      DOKUMENTART      NR       DATUM  \
# 0            18  PLENARPROTOKOLL    18/1  22.10.2013
# 0            18  PLENARPROTOKOLL    18/2  18.11.2013
# 0            18  PLENARPROTOKOLL    18/3  28.11.2013
# 0            18  PLENARPROTOKOLL    18/4  17.12.2013
# 0            18  PLENARPROTOKOLL    18/5  18.12.2013
# ..          ...              ...     ...         ...
# 0            19  PLENARPROTOKOLL  19/235  23.06.2021
# 0            19  PLENARPROTOKOLL  19/236  24.06.2021
# 0            19  PLENARPROTOKOLL  19/237  25.06.2021
# 0            19  PLENARPROTOKOLL  19/238  25.08.2021
# 0            19  PLENARPROTOKOLL  19/239  07.09.2021
#
#                              TITEL  \
# 0   Plenarprotokoll vom 22.10.2013
# 0   Plenarprotokoll vom 18.11.2013
# 0   Plenarprotokoll vom 28.11.2013
# 0   Plenarprotokoll vom 17.12.2013
# 0   Plenarprotokoll vom 18.12.2013
# ..                             ...
# 0   Plenarprotokoll vom 23.06.2021
# ...

# %%
#df.to_csv('data/protokolle.csv')
